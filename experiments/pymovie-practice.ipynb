# %%
from moviepy.editor import *

# %%
clip = VideoFileClip("../videos/test1.mp4").subclip(1)

# %%
clip.resize(width=480).ipython_display()
# Out:
# t:   0%|                                                                              | 0/92 [00:00<?, ?it/s, now=None]
# Moviepy - Building video __temp__.mp4.
# MoviePy - Writing audio in __temp__TEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# Moviepy - Writing video __temp__.mp4
# Moviepy - Done !
# Moviepy - video ready __temp__.mp4
# <div align=middle><video src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>

# %%
clip2 = VideoFileClip("../videos/test2.mp4").subclip(1)

# %%
clip2.resize(width=480).ipython_display()
# Out:
# chunk:  30%|███████████████████▍                                            | 28/92 [00:00<00:00, 274.52it/s, now=None]
# Moviepy - Building video __temp__.mp4.
# MoviePy - Writing audio in __temp__TEMP_MPY_wvf_snd.mp3
# t:   2%|█▍                                                                   | 5/250 [00:00<00:05, 41.34it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video __temp__.mp4
# Moviepy - Done !
# Moviepy - video ready __temp__.mp4
# <div align=middle><video src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>

# %%
video = CompositeVideoClip([clip,clip2.set_start(3)])

# %%
video.resize(width=480).ipython_display()
# Out:
# chunk:  18%|███████████▏                                                   | 28/158 [00:00<00:00, 271.93it/s, now=None]
# Moviepy - Building video __temp__.mp4.
# MoviePy - Writing audio in __temp__TEMP_MPY_wvf_snd.mp3
# t:   1%|▍                                                                    | 3/430 [00:00<00:15, 27.04it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video __temp__.mp4
# Moviepy - Done !
# Moviepy - video ready __temp__.mp4
# <div align=middle><video src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>
